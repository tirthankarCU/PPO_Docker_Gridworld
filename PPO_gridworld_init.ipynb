# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/drive/MyDrive/RL_NLP/RL_Agents/PPO_Agent

# %%
# %cd /content/drive/MyDrive/RL_NLP/RL_Agents/PPO_Agent
# Out:
# /content/drive/MyDrive/RL_NLP/RL_Agents/PPO_Agent

# %%
# !git clone https://github.com/tirthankarCU/PPO_Docker_Gridworld.git
# Out:
# Cloning into 'PPO_Docker_Gridworld'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 23 (delta 4), reused 23 (delta 4), pack-reused 0
# Unpacking objects: 100% (23/23), 13.29 KiB | 34.00 KiB/s, done.
